# %% [markdown]
# # Le verdict : ce qui meurt, ce qui survit · *The verdict: what dies, what survives*
#
# Notebook compagnon du chapitre **24. Multiplicateur monétaire ou création endogène** — [lire l'article](https://nmlab.io/ressources/multiplicateur-monetaire-ou-creation-endogene).
# Companion notebook to chapter **24. Money Multiplier or Endogenous Creation** — [read the article](https://nmlab.io/en/ressources/money-multiplier-or-endogenous-money).
#
# **Exécutez l'unique cellule ci-dessous** (bouton ▶ ou Ctrl+Entrée) : la figure est régénérée par le code — un **schéma éditable** : changez les libellés à votre guise. Passez `LANG = "en"` en tête de cellule pour les libellés anglais. — Run the single cell below (▶ or Ctrl+Enter) to rebuild the figure from code — an **editable diagram**: change the labels as you like; set `LANG = "en"` at the top for English labels.
#
# Code : licence MIT · © 2026 [NMLab](https://nmlab.io) · dépôt [nmlab-finance/nmlab-figures](https://github.com/nmlab-finance/nmlab-figures)

# %%
LANG = "fr"   # "fr" ou "en" — langue des libellés / label language

# Récupère puis active le style partagé NMLab (thème sombre + police Inter).
# Fetch and activate the shared NMLab style (dark theme + Inter font).
import urllib.request

urllib.request.urlretrieve("https://raw.githubusercontent.com/nmlab-finance/nmlab-figures/main/nmlab_style.py", "nmlab_style.py")
import nmlab_style as nm

nm.setup()


def verdict(lang: str) -> tuple[list[tuple[str, str]], list[tuple[str, str]]]:
    """Le verdict du procès : (ce qui meurt, ce qui survit), cartes (titre, détail).
    The trial's verdict: (what dies, what survives), cards (title, detail)."""
    if lang == "fr":
        dies = [
            ("Le levier quantitatif", "piloter la monnaie en dosant les réserves :\nabandonné par les banques centrales mêmes"),
            ("La causalité réserves → prêts", "aucune banque ne compte ses réserves\navant d'accorder un crédit"),
            ("« Prêter les dépôts »", "le dépôt est créé par le prêt —\nil n'existe pas avant lui"),
        ]
        survives = [
            ("Un ratio descriptif", "M2 ⁄ base se calcule toujours — après coup,\ncomme un thermomètre, pas un levier"),
            ("Le pilotage par le prix", "le taux directeur renchérit réserves et\nrefinancement : le vrai régulateur"),
            ("La fraction lue à l'envers", "Le Bourva (1962), puis le « diviseur » (1972) :\nles banques prêtent, la banque centrale fournit"),
        ]
    else:
        dies = [
            ("The quantity lever", "steering money by dosing reserves:\nabandoned by central banks themselves"),
            ("Reserves → loans causality", "no bank counts its reserves before\ngranting a loan"),
            ("\"Lending out deposits\"", "the deposit is created by the loan —\nit does not exist before it"),
        ]
        survives = [
            ("A descriptive ratio", "M2 ⁄ base can still be computed — after the\nfact, a thermometer, not a lever"),
            ("Steering by price", "the policy rate raises the cost of reserves\nand refinancing: the true regulator"),
            ("The fraction read backwards", "Le Bourva (1962), then the 1972 \"divisor\":\nbanks lend, the central bank supplies"),
        ]
    return dies, survives


from matplotlib.figure import Figure

LABELS = {
    "fr": dict(
        title="Le verdict : ce qui meurt, ce qui survit",
        sub="Le procès ne rend pas la monnaie illimitée — il déplace la contrainte, de la quantité vers le prix.",
        left="Ce qui meurt", right="Ce qui survit",
        note="Les quatre freins du chapitre 22 restent entiers : capital, rentabilité, demande solvable, liquidité.\n"
             "Ce qui disparaît, c'est l'idée d'un réservoir de réserves que les banques « multiplient »."),
    "en": dict(
        title="The verdict: what dies, what survives",
        sub="The trial does not make money limitless — it moves the constraint from quantity to price.",
        left="What dies", right="What survives",
        note="Chapter 22's four brakes stand untouched: capital, profitability, creditworthy demand, liquidity.\n"
             "What disappears is the idea of a pool of reserves that banks \"multiply\"."),
}

def build_figure(verdict_: tuple[list[tuple[str, str]], list[tuple[str, str]]], lang: str) -> Figure:
    """Deux colonnes de trois cartes : rose (meurt) à gauche, sarcelle (survit) à droite."""
    text = LABELS[lang]
    fig = nm.figure(height_px=1230)
    ax = nm.blank_axes(fig)

    dies, survives = verdict_
    col_w, x_left, x_right = 795, 62, 890
    top, card_h, gap = 1000, 250, 26

    for x, head, rows, color in ((x_left, text["left"], dies, "rose"),
                                 (x_right, text["right"], survives, "teal")):
        ax.text(x + 6, top + 44, head, ha="left", va="center", fontsize=27,
                fontweight="bold", color=nm.COLORS[color])
        for i, (t, d) in enumerate(rows):
            y = top - 40 - i * (card_h + gap)
            nm.card(ax, x, y - card_h, col_w, card_h, edge=nm.COLORS[color], lw=2.3, radius=22)
            ax.text(x + 38, y - 56, t, ha="left", va="center", fontsize=25,
                    fontweight="bold", color=nm.COLORS["text"])
            ax.text(x + 38, y - 116, d, ha="left", va="top", fontsize=20.5,
                    color=nm.COLORS["muted"], linespacing=1.5)

    nm.header(fig, text["title"], text["sub"])
    nm.footer(fig, text["note"])
    return fig

build_figure(verdict(LANG), LANG)
