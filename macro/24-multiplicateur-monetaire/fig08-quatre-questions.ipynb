# %% [markdown]
# # Quatre questions avant de crier à la planche à billets · *Four questions before crying "money printer"*
#
# Notebook compagnon du chapitre **24. Multiplicateur monétaire ou création endogène** — [lire l'article](https://nmlab.io/ressources/multiplicateur-monetaire-ou-creation-endogene).
# Companion notebook to chapter **24. Money Multiplier or Endogenous Creation** — [read the article](https://nmlab.io/en/ressources/money-multiplier-or-endogenous-money).
#
# **Exécutez l'unique cellule ci-dessous** (bouton ▶ ou Ctrl+Entrée) : la figure est régénérée par le code — un **schéma éditable** : changez les libellés à votre guise. Passez `LANG = "en"` en tête de cellule pour les libellés anglais. — Run the single cell below (▶ or Ctrl+Enter) to rebuild the figure from code — an **editable diagram**: change the labels as you like; set `LANG = "en"` at the top for English labels.
#
# Code : licence MIT · © 2026 [NMLab](https://nmlab.io) · dépôt [nmlab-finance/nmlab-figures](https://github.com/nmlab-finance/nmlab-figures)

# %%
LANG = "fr"   # "fr" ou "en" — langue des libellés / label language

# Récupère puis active le style partagé NMLab (thème sombre + police Inter).
# Fetch and activate the shared NMLab style (dark theme + Inter font).
import urllib.request

urllib.request.urlretrieve("https://raw.githubusercontent.com/nmlab-finance/nmlab-figures/main/nmlab_style.py", "nmlab_style.py")
import nmlab_style as nm

nm.setup()


def questions(lang: str) -> list[tuple[str, str]]:
    """La grille de lecture en quatre questions : (question, réponse-clé).
    The four-question reading grid: (question, key answer)."""
    if lang == "fr":
        return [
            ("1. Quelle monnaie ?",
             "La base (réserves) tourne en circuit fermé ;\nla monnaie large (M2, M3) achète biens et actifs."),
            ("2. Qui la reçoit ?",
             "Un échange d'actifs entre banques n'est pas\nun virement aux ménages."),
            ("3. Contre quoi est-elle née ?",
             "Crédit privé, déficit public, devises :\nles portes du chapitre 23."),
            ("4. Dans quel régime ?",
             "Inflation basse : signal faible. Poussée :\nla monnaie large redevient parlante (BRI, 2023)."),
        ]
    return [
        ("1. Which money?",
         "The base (reserves) runs in a closed circuit;\nbroad money (M2, M3) buys goods and assets."),
        ("2. Who receives it?",
         "An asset swap between banks is not\na transfer to households."),
        ("3. What was it born against?",
         "Private credit, public deficits, foreign\ncurrency: chapter 23's doors."),
        ("4. In which regime?",
         "Low inflation: a weak signal. A surge:\nbroad money speaks again (BIS, 2023)."),
    ]


from matplotlib.figure import Figure

LABELS = {
    "fr": dict(
        title="Quatre questions avant de crier à la planche à billets",
        sub="La grille qui sépare un gros bilan de banque centrale d'une vraie impulsion monétaire.",
        note="La lettre de 2010 échouait aux questions 1 et 2 ; ceux qui ont balayé M2 en 2020-2021\n"
             "échouaient à la quatrième."),
    "en": dict(
        title="Four questions before crying \"money printer\"",
        sub="The grid that separates a large central-bank balance sheet from a true monetary impulse.",
        note="The 2010 letter failed questions 1 and 2; those who waved away M2 in 2020-2021\n"
             "failed the fourth."),
}

def build_figure(questions_: list[tuple[str, str]], lang: str) -> Figure:
    """Grille 2 × 2 de cartes question/réponse."""
    text = LABELS[lang]
    fig = nm.figure(height_px=1150)
    ax = nm.blank_axes(fig)

    card_w, card_h, gap_x, gap_y, x0, top = 792, 330, 39, 40, 62, 900
    for i, (q, a) in enumerate(questions_):
        x = x0 + (i % 2) * (card_w + gap_x)
        y = top - (i // 2) * (card_h + gap_y)
        nm.card(ax, x, y - card_h, card_w, card_h, edge=nm.COLORS["blue"], lw=2.4, radius=22)
        ax.text(x + 42, y - 62, q, ha="left", va="center", fontsize=27,
                fontweight="bold", color=nm.COLORS["blue"])
        ax.text(x + 42, y - 128, a, ha="left", va="top", fontsize=21.5,
                color=nm.COLORS["muted"], linespacing=1.55)

    nm.header(fig, text["title"], text["sub"])
    nm.footer(fig, text["note"])
    return fig

build_figure(questions(LANG), LANG)
